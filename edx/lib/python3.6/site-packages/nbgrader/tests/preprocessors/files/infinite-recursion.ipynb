# %%
def foo():
    foo()
    
foo()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-1de558252cc3> in <module>()
#       2     foo()
#       3
# ----> 4 foo()
#
# <ipython-input-3-1de558252cc3> in foo()
#       1 def foo():
# ----> 2     foo()
#       3
#       4 foo()
#
# <ipython-input-3-1de558252cc3> in foo()
#       1 def foo():
# ----> 2     foo()
#       3
#       4 foo()
#
# <ipython-input-3-1de558252cc3> in foo()
#       1 def foo():
# ----> 2     foo()
#       3
#       4 foo()
#
# <ipython-input-3-1de558252cc3> in foo()
#       1 def foo():
# ----> 2     foo()
#       3
#       4 foo()
#
# <ipython-input-3-1de558252cc3> in foo()
#       1 def foo():
# ----> 2     foo()
#       3
#       4 foo()
#
# <ipython-input-3-1de558252cc3> in foo()
#       1 def foo():
# ----> 2     foo()
#       3
#       4 foo()
#
# <ipython-input-3-1de558252cc3> in foo()
#       1 def foo():
# ----> 2     foo()
# ...
