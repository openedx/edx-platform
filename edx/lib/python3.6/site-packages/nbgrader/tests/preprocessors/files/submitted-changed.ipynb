# %%
# YOUR CODE HERE
a = 1

# %%
print("Success!")
# Out:
# Success!

# %%
assert a == 1

# %% [markdown]
# An answer!

# %%
# YOUR CODE HERE
b = 2

# %%
print("Don't change this cell!")
# Out:
# Don't change this cell!

# %% [markdown]
# This cell shouldn't be changed.
